# %%
import numpy as np
from scipy import stats
import seaborn as sns
import pandas as pd
from IPython.display import display 
import matplotlib
import matplotlib.pyplot as plt

myds =pd.read_csv("insurance.csv")

# %%
myds.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
myds.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sns.heatmap(myds.corr(), annot=True, linewidths=.5, fmt= '.1f')
plt.show()

# %%
sns.barplot(myds['children'],myds['age'],hue=myds['smoker'])

# %%
sns.countplot(myds['children'])

# %%
sns.pointplot(myds['sex'],myds['bmi'],hue=myds['smoker'])

# %%
myds.shape
# Out:
# (1338, 7)

# %%
sns.jointplot(myds['charges'],myds['sex'])

# %%
sns.stripplot(myds['charges'],myds['sex'],jitter=True)

# %%
sns.boxplot(myds['charges'])

# %%
sns.lmplot(x="bmi", y="charges",hue="smoker", data=myds)
